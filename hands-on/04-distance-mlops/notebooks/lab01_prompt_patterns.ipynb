# %% [markdown]
# # Lab 1 — Prompt patterns for logs & tickets
#
# System · user · constraints · few-shot.

# %% [markdown]
# **Router log summarization system prompt**
#
# You summarize syslog lines for TAC. Output: 2 bullets + severity guess (low/medium/high).
#
# **Few-shot user example**
#
# Log: `E-BGP neighbor down RTR-AUS-03`
# Summary:
# - BGP session lost on RTR-AUS-03
# - Severity: high

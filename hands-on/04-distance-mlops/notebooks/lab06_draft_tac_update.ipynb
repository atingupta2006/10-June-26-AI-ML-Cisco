# %% [markdown]
# # Lab 6 — Draft TAC customer update (prompt template)

# %%
findings = ["E-404 on RTR-LON-07", "Config drift on VLAN 12", "Change window Sunday 02:00 UTC"]
prompt = f'''Draft a polite 3-sentence customer status update. No internal jargon.
Findings: {findings}'''
print(prompt)
print("\n--- Paste to your LLM or local SLM ---")

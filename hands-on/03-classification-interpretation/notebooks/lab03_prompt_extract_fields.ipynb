# %% [markdown]
# # Lab 3 — Prompt engineering: extract fields
#
# Write a prompt template (no API key required in this lab).

# %%
ticket = "Customer reports VPN tunnel drop on IOS-XE; intermittent since last change window."
prompt = f'''Extract JSON with keys product, feature, severity guess.
Ticket: {ticket}
JSON:'''
print("PROMPT:\n", prompt)
# Expected shape: {"product": "IOS-XE", "feature": "VPN tunnel drop", ...}
# Out:
# PROMPT:
#  Extract JSON with keys product, feature, severity guess.
# Ticket: Customer reports VPN tunnel drop on IOS-XE; intermittent since last change window.
# JSON:

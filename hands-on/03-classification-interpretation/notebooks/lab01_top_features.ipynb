# %% [markdown]
# # Lab 1 — Which feature is reported most?
#
# **Ticket analysis** — no confusion matrix.

# %%
from pathlib import Path

import pandas as pd

GH_ROOT = Path.cwd().resolve()
if GH_ROOT.name == "notebooks":
    GH_ROOT = GH_ROOT.parents[2]
else:
    for p in [GH_ROOT, *GH_ROOT.parents]:
        if (p / "data" / "support-ops").is_dir():
            GH_ROOT = p
            break
SUPPORT_OPS = GH_ROOT / "data" / "support-ops"

import matplotlib.pyplot as plt

tickets = pd.read_csv(SUPPORT_OPS / "support_tickets.csv")
top = tickets["feature"].value_counts().head(10)
print(top)
top.plot(kind="barh", figsize=(7, 4), title="Top 10 reported features")
plt.tight_layout()
plt.show()
# Out:
# feature
# VPN tunnel drop       117
# BGP peering           104
# Interface flapping     85
# CPU spike              79
# Memory leak            73
# License activation     67
# Firmware upgrade       62
# Auth failure           47
# DNS resolution         46
# Config sync            43
# Name: count, dtype: int64

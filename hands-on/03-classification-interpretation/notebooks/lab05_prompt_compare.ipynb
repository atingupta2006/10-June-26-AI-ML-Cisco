# %% [markdown]
# # Lab 5 — Bad vs good prompt

# %%
text = "Interface flapping on RTR-SJC-12; BGP notifications; customer escalated."
bad = f"Summarize: {text}"
good = '''You are a TAC engineer. Summarize in 2 bullets for shift handoff.
Use only the text below. No root cause speculation.
---
''' + text
print("BAD:\n", bad, "\n\nGOOD:\n", good)

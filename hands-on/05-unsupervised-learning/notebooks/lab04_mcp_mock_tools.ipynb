# %% [markdown]
# # Lab 4 — MCP-style mock tools
#
# Python functions an agent can call.

# %%
from pathlib import Path

import pandas as pd

GH_ROOT = Path.cwd().resolve()
if GH_ROOT.name == "notebooks":
    GH_ROOT = GH_ROOT.parents[2]
else:
    for p in [GH_ROOT, *GH_ROOT.parents]:
        if (p / "data" / "support-ops").is_dir():
            GH_ROOT = p
            break
SUPPORT_OPS = GH_ROOT / "data" / "support-ops"

def get_ticket(ticket_id: str) -> dict:
    t = pd.read_csv(SUPPORT_OPS / "support_tickets.csv")
    row = t[t["ticket_id"] == ticket_id].iloc[0]
    return row.to_dict()

def log_summary_last_24h() -> str:
    r = pd.read_csv(SUPPORT_OPS / "router_logs.csv", parse_dates=["timestamp"])
    top = r["error_code"].value_counts().head(3)
    return "Top router errors: " + ", ".join(f"{k}({v})" for k, v in top.items())

print(get_ticket("T00001"))
print(log_summary_last_24h())
# Out:
# {'ticket_id': 'T00001', 'created_date': '2025-11-24', 'product': 'IOS-XE', 'feature': 'VPN tunnel drop', 'severity': 'low', 'summary': 'Customer reports vpn tunnel drop on IOS-XE; intermittent since last change window.', 'status': 'resolved', 'resolved_days': 12.0}
# Top router errors: E-0(138), E-101(93), E-VPN(85)

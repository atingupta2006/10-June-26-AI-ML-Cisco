# %% [markdown]
# # Lab 6 — Automation idea (group discussion)
#
# Pick **one**:
#
# - Auto-summarize new **router** log bundle
# - Weekly **bug trend** email from tickets
# - RAG assistant over **runbook** for L1
#
# Write: data source · Gen AI or classical · human approval step.

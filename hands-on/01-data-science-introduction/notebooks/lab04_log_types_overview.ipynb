# %% [markdown]
# # Lab 4 — Log & ticket file overview
#
# Preview **networking, router, security** data.

# %%
from pathlib import Path

import pandas as pd

GH_ROOT = Path.cwd().resolve()
if GH_ROOT.name == "notebooks":
    GH_ROOT = GH_ROOT.parents[2]
else:
    for p in [GH_ROOT, *GH_ROOT.parents]:
        if (p / "data" / "support-ops").is_dir():
            GH_ROOT = p
            break
SUPPORT_OPS = GH_ROOT / "data" / "support-ops"

for name in ["support_tickets.csv", "network_events.csv", "router_logs.csv", "security_logs.csv"]:
    path = SUPPORT_OPS / name
    df = pd.read_csv(path, nrows=5)
    print("\n===", name, "===")
    print(df)
# Out:
# === support_tickets.csv ===
#   ticket_id created_date product             feature severity  \
# 0    T00001   2025-11-24  IOS-XE     VPN tunnel drop      low
# 1    T00002   2025-02-22   Webex        Auth failure   medium
# 2    T00003   2025-01-16  IOS-XE         BGP peering   medium
# 3    T00004   2025-04-12   Webex  License activation   medium
# 4    T00005   2025-05-23  IOS-XE        Auth failure      low
#
#                                              summary    status  resolved_days
# 0  Customer reports vpn tunnel drop on IOS-XE; in...  resolved           12.0
# 1  Customer reports auth failure on Webex; interm...  resolved            1.0
# 2  Customer reports bgp peering on IOS-XE; interm...      open            NaN
# 3  Customer reports license activation on Webex; ...  resolved           10.0
# 4  Customer reports auth failure on IOS-XE; inter...  resolved            5.0
#
# === network_events.csv ===
#           timestamp device_type device_id site     event_type    bytes  \
# 0  2025-10-25 17:00      switch   SWI-047  LON        latency  4027145
# 1  2025-09-02 21:00      server   SER-063  SJC  config_change  1475466
# 2  2025-02-25 23:00          vm    VM-110  NYC        latency  1648790
# 3  2025-02-22 04:00      server   SER-115  NYC        traffic   262676
# 4  2025-10-04 13:00      server   SER-028  NYC        traffic  2187208
#
#    latency_ms
# 0       55.81
# 1       77.64
# 2       31.96
# 3       97.61
# 4       65.44
#
# === router_logs.csv ===
#           timestamp   router_id site  \
# 0  2025-02-07 02:00  RTR-SJC-04  SJC
# 1  2025-03-15 01:00  RTR-LON-39  LON
# 2  2025-11-25 16:00  RTR-LON-04  LON
# 3  2025-12-15 17:00  RTR-SJC-14  SJC
# 4  2025-12-05 03:00  RTR-AUS-15  AUS
#
#                                        message error_code severity
# 0    Syslog: E-0 interface event on RTR-SJC-04        E-0     high
# 1    Syslog: E-0 interface event on RTR-LON-39        E-0   medium
# 2    Syslog: E-0 interface event on RTR-LON-04        E-0     high
# 3  Syslog: E-404 interface event on RTR-SJC-14      E-404     high
# 4  Syslog: E-VPN interface event on RTR-AUS-15      E-VPN     high
#
# === security_logs.csv ===
#           timestamp          source   event_type severity  is_alert
# 0  2025-05-14 23:00     10.66.73.58   login_fail      low         0
# 1  2025-02-26 02:00  10.206.144.228       normal      low         0
# 2  2025-03-13 20:00    10.94.154.85    port_scan     high         1
# 3  2025-11-12 11:00    10.136.67.84       normal      low         0
# 4  2025-10-16 02:00    10.74.17.192  policy_deny      low         0

# %% [markdown]
# # Lab 2 — TAC scenario → data cycle
#
# Map: *"VPN drops after firmware upgrade — 40 tickets this week"*

# %% [markdown]
# Fill CRISP-DM phases:
#
# - Business understanding:
# - Data understanding:
# - Data preparation:
# - Modeling / assist:
# - Evaluation:
# - Deployment (concept):

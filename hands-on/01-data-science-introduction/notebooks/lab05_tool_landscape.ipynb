# %% [markdown]
# # Lab 5 — Tools for support automation
#
# | Phase | Tool |
# |-------|------|
# | Explore | pandas, Seaborn |
# | Gen AI | Hugging Face, prompts, local SLM |
# | Knowledge | RAG, `kb_snippets.txt` |
# | Integrate | MCP-style Python tools |

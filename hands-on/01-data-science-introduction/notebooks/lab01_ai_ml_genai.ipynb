# %% [markdown]
# # Lab 1 — AI, ML & Gen AI (support context)
#
# **Day 01** · Map terms to product support scenarios.

# %% [markdown]
# ## Worksheet
#
# 1. **AI** example from support: _e.g. trend dashboard flagging spike in router errors_
# 2. **ML** example: _grouping similar tickets without labels_
# 3. **Gen AI** example: _draft TAC update from bullet notes_
# 4. Which needs **labeled history**? Which needs **your KB/docs**?

# %% [markdown]
# # Lab 2 — Data Science Cycle (CRISP-DM)
#
# **Day 01 · Data Science Introduction · Cisco AI/ML Training**
#
# ---
#
# ## Learning objectives
#
# 1. Name the **six CRISP-DM phases** in order.
# 2. Map each phase to an **activity** and **deliverable** for a business problem.
# 3. Apply the cycle to the Day 1 **team sales** question.
# 4. Identify phases that apply **without** building an ML model.
#
# > **Checkpoint:** all **six** phases in order · activity + deliverable per phase
#
# **Format:** Worksheet / group discussion (no verification script)

# %% [markdown]
# ---
#
# **Day 1 flow:** Lab 1 concepts → **Lab 2 (you are here)** → Labs 3–4 analyze `team_sales.csv` → Lab 5 tools → Lab 6 applies this cycle in Excel.

# %% [markdown]
# ## Why this matters
#
# <!-- cisco-enrich-2026-06 -->
#
# CRISP-DM is the **shared language** between business sponsors and data teams. When a stakeholder asks for "AI," mapping their ask to a phase prevents skipping data quality work or deploying models without evaluation.

# %% [markdown]
# ## CRISP-DM lifecycle
#
# ```text
# Business Understanding → Data Understanding → Data Preparation
#         → Modeling → Evaluation → Deployment
# ```
#
# Not every project needs **Modeling** (e.g. Excel pivot answers many business questions).

# %% [markdown]
# ---
#
# ## 1. Six phases (reference)

# %%
CRISP_DM_PHASES = [
    "Business Understanding",
    "Data Understanding",
    "Data Preparation",
    "Modeling",
    "Evaluation",
    "Deployment",
]

for i, phase in enumerate(CRISP_DM_PHASES, start=1):
    print(f"{i}. {phase}")

# %% [markdown]
# ---
#
# ## 2. Worked example — team sales (Day 1 capstone preview)

# %%
import pandas as pd
from IPython.display import display

business_question = "Which region had the highest Q2 sales?"

team_sales_example = pd.DataFrame({
    "phase": CRISP_DM_PHASES,
    "activity": [
        "Define regional performance KPI",
        "Open team_sales.csv; profile 20 teams, 4 regions",
        "Ensure numeric columns; handle blanks",
        "Optional forecast (not required Day 1)",
        "Compare regional Q2 totals; count growth teams",
        "Share chart with manager / stakeholders",
    ],
    "deliverable": [
        "Problem statement",
        "EDA summary",
        "Analysis-ready table",
        "Model artifact (if used)",
        "Regional ranking answer",
        "Presentation or email report",
    ],
    "needs_ml": ["No", "No", "No", "Optional", "No", "No"],
})

print(f"Business question: {business_question}")
display(team_sales_example)

# %% [markdown]
# Excel pivot / `SUMIF` in Lab 6 fits **Data Preparation → Evaluation** — DS without ML.

# %% [markdown]
# ---
#
# ## 3. Your group's problem (edit below)

# %%
group_question = "Which store region had highest Q2 sales?"  # change if your table picks another

group_plan = pd.DataFrame({
    "phase": CRISP_DM_PHASES,
    "activity": [
        "Define KPI",
        "Profile CSV",
        "Clean missing values",
        "Build model (if needed)",
        "Validate answer",
        "Deliver report",
    ],
    "deliverable": [
        "Problem statement",
        "EDA summary",
        "Analysis-ready table",
        "Model or N/A",
        "Metrics / chart",
        "Stakeholder deck",
    ],
})

print(f"Group question: {group_question}")
display(group_plan)

# %% [markdown]
# ---
#
# ## 4. Phases without ML

# %%
no_ml_phases = [
    "Business Understanding",
    "Data Understanding",
    "Data Preparation",
    "Evaluation",
    "Deployment",
]

print("Phases that apply even without ML:")
for p in no_ml_phases:
    print(f"  • {p}")

# %% [markdown]
# ---
#
# ## 5. Map to Cisco training week (preview)

# %%
course_map = pd.DataFrame({
    "day": ["01", "02", "03", "04", "05", "06"],
    "emphasis": [
        "Business + Data Understanding",
        "Data Prep + Modeling (regression)",
        "Modeling + Evaluation (classification)",
        "Modeling + Deployment (API, MLflow)",
        "Modeling (clustering)",
        "Evaluation + Deployment (fraud report)",
    ],
})
display(course_map)

# %% [markdown]
# ---
#
# ## 6. Checkpoint self-check

# %%
assert len(CRISP_DM_PHASES) == 6
assert CRISP_DM_PHASES[0] == "Business Understanding"
assert CRISP_DM_PHASES[-1] == "Deployment"
assert len(group_plan) == 6
assert all(group_plan["activity"].str.len() > 3)
assert all(group_plan["deliverable"].str.len() > 3)
print("✓ Worksheet checkpoint passed — six phases mapped")

# %% [markdown]
# ## Extension — map team sales to CRISP-DM
#
# For *"Which region had the strongest Q2 growth?"* fill this table in your worksheet:
#
# | Phase | One activity | One deliverable |
# |-------|--------------|------------------|
# | Business Understanding | | |
# | Data Understanding | | |
# | Data Preparation | | |
# | Modeling | (optional) | |
# | Evaluation | | |
# | Deployment | | |

# %% [markdown]
# ---
#
# ## Reflection questions
#
# 1. Where does **Excel** fit in CRISP-DM for Lab 6?
# 2. Which phase is often skipped in rushed projects — and why is that risky?
# 3. How does **MLflow** (Day 4) support Evaluation and Deployment?
#
# **Previous:** [Lab 1 — AI vs ML vs DS](lab01_ai_ml_ds.ipynb)
# **Next:** [Lab 3 — Statistics basics](lab03_statistics_basics.ipynb)

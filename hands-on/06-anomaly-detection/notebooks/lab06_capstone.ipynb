# %% [markdown]
# # Lab 6 — Automation capstone
#
# Present: insight · Gen AI/RAG/agent idea · human approval gate.

# %% [markdown]
# **Deliverable (2–3 slides or markdown)**
#
# 1. One **trend** chart (bugs or router errors)
# 2. One **top feature** finding
# 3. One **agentic** flow using MCP-style tools from Day 5
# 4. What you will **not** automate without human review

# %%
from pathlib import Path

import pandas as pd

GH_ROOT = Path.cwd().resolve()
if GH_ROOT.name == "notebooks":
    GH_ROOT = GH_ROOT.parents[2]
else:
    for p in [GH_ROOT, *GH_ROOT.parents]:
        if (p / "data" / "support-ops").is_dir():
            GH_ROOT = p
            break
SUPPORT_OPS = GH_ROOT / "data" / "support-ops"

print("Capstone checklist:")
print(" [ ] bug_trend_report.png")
print(" [ ] top_features_report.json")
print(" [ ] agent flow described")
# Out:
# Capstone checklist:
#  [ ] bug_trend_report.png
#  [ ] top_features_report.json
#  [ ] agent flow described
